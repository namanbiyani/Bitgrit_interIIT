# %%
import pandas as pd
import numpy as np

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
test = pd.read_csv('test.csv')

# %%
test.head()
# Out:
#                                              id  span  feature_00  feature_01  \
# 0  M0E4UFFiUkU0emNkOVlHbBAR9AAPSU6QvT49pfCItDo=    21    0.584701    0.680847
# 1  M0NLYVNZWjBjeTd1ZlBBUlngURLdbSgtBJeiqYUNosY=    15    0.294058   -0.042161
# 2  M0dDbHlMUTY5SzV0ZTBvQb9h8YABlnerdSpsViBIYVU=    19   -0.758543    1.117410
# 3  M1JHMHhkeWlZZnJ6N01objC3E5eNJCB8DbIUbwPy/qQ=    24    0.686334    0.880205
# 4  M1dyQXB1OUZtNEpNaE5iWcovkHOs4gcR3kGXY4xfyvo=    21    0.939746    0.733183
#
#    feature_02  feature_03  feature_04  feature_05  feature_06  feature_07  \
# 0    1.274691    0.822238   -0.704789    0.618635    1.008875   -1.343878
# 1   -0.634547   -1.867351    1.326732   -0.514469   -0.882709    0.358100
# 2    1.207818    1.524244   -0.411981   -1.722889    0.936596   -0.057886
# 3   -0.362334   -0.309460   -1.032071    1.646878    0.492463    0.236905
# 4   -0.747184   -0.705871    0.760725    1.153195   -0.230777   -0.285860
#
# ...

# %%
test = test.set_index('id')

# %%
test['pred'] = 1
pred = test[['pred']]
pred = pred.sort_index(ascending=False)

# %%
# for i in range(100):
#     output[i] = pred[]

# %%
pred.iloc[0:5,:] += 0.005
pred.iloc[5:10,:] -= 0.005

# %%
pred.iloc[:20,:]
# Out:
#                                                pred
# id
# enh2dWc5Q3lKSWF3U1hEV+/abiID/K7yVOPVBygGuVA=  1.005
# endjOU4wQnR4cE9LMzdabGrBw0Q1qGC7AU9l3GNJ39s=  1.005
# enNwTlhiRVZvZ1REdjJ0M7+RvxILEKLqCPVe6hmsorY=  1.005
# enFPQkh1MjhDbzNYTkpSaPUNwYeUYAPoFTycmmFLs78=  1.005
# enBMUTZxR1I0b3dFa3VNQgWtG0vsXSAk8ohZ9IP1cfM=  1.005
# em9KZnE3NHlMYlhqaFlQWpIlwIhZLFroR/FJ+iX8ydY=  0.995
# elpKN0xST1c2bWppclh4OJv0FtQJS+3ZfnWNxvvweAw=  0.995
# elhuU0xkOFBxa2Z2UkJiTVckneGlvcZruZVaT0meiFc=  0.995
# eldtNGxLaENBY1hMWTdHMDSnX+JzT5j5KOeD5A5r/fU=  0.995
# elVuNzlCSTRtaGFwRWxTZ5+4CTEisrRPBxJ2bYauUSc=  0.995
# elR5RjhKTWk5QVZPcjdRRX3fIcCUXaN2qTqg/7IOFtA=  1.000
# ekk3ckRsMjVMTkJKOEZaZDwpADBuMRz9KxhizMxFOUA=  1.000
# ekgzb0tmc1RBRG5MZ2VCecGpq8lSxU3G5YGToTn5nKs=  1.000
# ekZqb1B4djhPTW1CY2kza5NJouW3GopRyZ59e58s3p8=  1.000
# ekRtME5UbnRjRWlhM2xMONF9Myv3HYAgG5jLnfBI4Dk=  1.000
# ejl2ODBQeWNvakJPTXVyVP13U/XE10G+jSlm4eez6zQ=  1.000
# ejhLblhVWUR0UXJncFRzOagEKpoSNvtikOJrdO0OFG4=  1.000
# ...

# %%
pred.to_csv('output1.csv')

# %%
import os
from selenium import webdriver

# %%
driver = webdriver.Chrome()
driver.implicitly_wait(10)
driver.get('https://interiit.bitgrit.net/competition/1#')

# %%
driver.find_element_by_xpath('//input[@accept=".csv"]').send_keys(os.getcwd()+'/output.csv')

# %%
driver.find_element_by_xpath('//input[@type="submit"]').click()

# %%
driver.find_element_by_id('btn-submission').click()

# %%
driver.find_element_by_id('first-submission').click()
